# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
r1 = 20
r2 = 80
d1 = 30
d2 = 60
r = 50

# %%
d = d2 * (r - r1) / (r2 - r1) + d1

# %%
x = (r1, r2, r)
y = (d1, d2, d)
plt.plot(x, y, '.')
plt.xlim((0, 100))
plt.ylim((0, 100))
plt.show()
